# %% [markdown]
# <a href="https://colab.research.google.com/github/seirah-yang/F_roject/blob/main/14_%EC%8B%9C%EA%B0%84%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%B2%98%EB%A6%AC.../.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) 시간 데이터를 불러오거나 새롭게 생성
# 2) 시간데이터를 이용하여 특정 시간 데이터를 추출
# 3) 시간차이 계산 방법
#
# ## 시간데이터 생성하기
# - 의료데이터에서 날짜 및 시간 데이터를 표준화 또는 차이를 계산하는 등을 처리하는 과정이 필요
# - python에서는 pandas라이브러리의 Timestamp, DatetimeIndex, to_datetime 객체 혹은 함수
# -  혹은 datetime라이브러리의 date, time, datetime, timedelta 클래스들을 사용하여 데이터를 처리
# - 환자의 진료기록, 약물처방 기록 등 날짜와 시간을 처리 및 관리용도로 사용된다.

# %%
# datetime- "date" 클래스 : year, month, date를 속성으로 가진 날짜 객체를 표현
# today 함수로 현재 날짜를 출력하여 날짜의 세부정보를 확인 가능함

#datetime 라이브러리에서 date class가져오기
from datetime import date
dy1= date(2025,9,8)
dy1
# Out:
# datetime.date(2025, 9, 8)

# %%
dy2 = date.today()
print(dy2)
print('Day: ',  dy2.day)
# Out:
# 2025-09-11
# Day:  11

# %%
print('month:' , dy2.month)
# Out:
# month: 9

# %%
"year:", dy2.year
# Out:
# ('year:', 2025)

# %%
from datetime import time
# 시간 객체 생성: 시, 분, 초, 마이크로초
tm1 = time(13, 20, 13, 40)
print(tm1)
print(type(tm1))
# Out:
# 13:20:13.000040
# <class 'datetime.time'>

# %%
<class 'datetime.time'>
# Out:
#   File "/tmp/ipython-input-1003330313.py", line 1
#     <class 'datetime.time'>
#     ^
# SyntaxError: invalid syntax

# %%
import datetime
import pandas as pd
import numpy as np
# 다양한 날짜 형식: 1/1/2023 , 2023-01-01 , 2023,1,1
dti = pd.to_datetime(["1/1/2023", np.datetime64("2023-01-01"), datetime.datetime(2023, 1, 1)])
print(dti)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-01', '2023-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# 2023년 9월 8일
pd.to_datetime("2023/09/08", format = "%Y/%m/%d")
# 출력: Timestamp ('2023-09-08 00:00:00')


# 2023년 9월 8일 10시 9분
pd.to_datetime("08-09-2023 10:09", format = "%d-%m-%Y %H:%M")
# 출력: Timestamp ('2023-09-08 10:09:00')
# Out:
# Timestamp('2023-09-08 10:09:00')

# %%
# 필요한 라이브러리 임포트
import pandas as pd
import numpy as np

covid_path = '/content/COVID clinical trials.csv'
# COVID 데이터 불러오기
df = pd.read_csv(covid_path)
# COVID 각 열 2개 상위 3행으로 데이터프레임 생성
test = df[['Start Date', 'Completion Date']].head(3)
print (test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1142168594.py in <cell line: 0>()
#       5 covid_path = '/content/COVID clinical trials.csv'
#       6 # COVID 데이터 불러오기
# ----> 7 df = pd.read_csv(covid_path)
#       8 # COVID 각 열 2개 상위 3행으로 데이터프레임 생성
#       9 test = df[['Start Date', 'Completion Date']].head(3)
#
# ...

# %%
# 필요한 라이브러리 지정
import pandas as pd
from datetime import datetime, timedelta

# datetime.strptime 함수로 날짜 객체 (%B %d, %Y)로 설정
test['d_std'] = test['Start Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
print(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3582568525.py in <cell line: 0>()
#       4
#       5 # datetime.strptime 함수로 날짜 객체 (%B %d, %Y)로 설정
# ----> 6 test['d_std'] = test['Start Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
#       7 print(test)
#
# NameError: name 'test' is not defined

# %%
column_dtype = test['d_std'].dtype
print(column_dtype)
# 출력: datetime64[ns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1001239699.py in <cell line: 0>()
# ----> 1 column_dtype = test['d_std'].dtype
#       2 print(column_dtype)
#       3 # 출력: datetime64[ns]
#
# NameError: name 'test' is not defined

# %%
# 필요한 라이브러리 지정
import pandas as pd
from datetime import datetime, timedelta

# date (2자리)/ month (2자리)/ year (4자리) hour (24시간) : minute (2자리) 로 표현
test['d_std_date'] = test['d_std'].apply(lambda x: x.strftime('%d/%m/%Y %H:%M'))
print (test)
# 출력:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1877304104.py in <cell line: 0>()
#       4
#       5 # date (2자리)/ month (2자리)/ year (4자리) hour (24시간) : minute (2자리) 로 표현
# ----> 6 test['d_std_date'] = test['d_std'].apply(lambda x: x.strftime('%d/%m/%Y %H:%M'))
#       7 print (test)
#       8 # 출력:
#
# NameError: name 'test' is not defined

# %%
import pandas as pd
from datetime import datetime, timedelta

# Start Date와 Completion Date를 timedelta 객체로 변환
test['d_std'] =  test['Start Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
test['d_comp'] =  test['Completion Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))

# 날짜 차이를 계산한 후 출력
test['duration'] = test['d_comp'] - test['d_std']
print (test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-915664596.py in <cell line: 0>()
#       3
#       4 # Start Date와 Completion Date를 timedelta 객체로 변환
# ----> 5 test['d_std'] =  test['Start Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
#       6 test['d_comp'] =  test['Completion Date'].apply(lambda x: datetime.strptime(x, '%B %d, %Y'))
#       7
#
# NameError: name 'test' is not defined

# %%
test['duration_hr'] = test['duration'].apply(lambda x: x/timedelta(hours = 1))
test['duration_min'] = test['duration'].apply(lambda x: x/timedelta(minutes = 1))
test['duration_sec'] = test['duration'].apply(lambda x: x/timedelta(seconds = 1))
print (test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-775214312.py in <cell line: 0>()
# ----> 1 test['duration_hr'] = test['duration'].apply(lambda x: x/timedelta(hours = 1))
#       2 test['duration_min'] = test['duration'].apply(lambda x: x/timedelta(minutes = 1))
#       3 test['duration_sec'] = test['duration'].apply(lambda x: x/timedelta(seconds = 1))
#       4 print (test)
#
# NameError: name 'test' is not defined
